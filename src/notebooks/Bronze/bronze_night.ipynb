# %%
import pandas as pd
import re

urls = [
    "https://docs.google.com/spreadsheets/d/15zsK-lBuibUtZ1s2FxVHvAmSu-pEuE0NDT6CAMYL2TY/edit?gid=599101906#gid=599101906",
    "https://docs.google.com/spreadsheets/d/15zsK-lBuibUtZ1s2FxVHvAmSu-pEuE0NDT6CAMYL2TY/edit?gid=45136115#gid=45136115",
    "https://docs.google.com/spreadsheets/d/15zsK-lBuibUtZ1s2FxVHvAmSu-pEuE0NDT6CAMYL2TY/edit?gid=1960490105#gid=1960490105",
    "https://docs.google.com/spreadsheets/d/15zsK-lBuibUtZ1s2FxVHvAmSu-pEuE0NDT6CAMYL2TY/edit?gid=0#gid=0",
    "https://docs.google.com/spreadsheets/d/15zsK-lBuibUtZ1s2FxVHvAmSu-pEuE0NDT6CAMYL2TY/edit?gid=1134450809#gid=1134450809",
    "https://docs.google.com/spreadsheets/d/15zsK-lBuibUtZ1s2FxVHvAmSu-pEuE0NDT6CAMYL2TY/edit?gid=358021773#gid=358021773",
]

names = [
    "night_agencies",
    "night_stops",
    "night_routes",
    "night_trips",
    "night_trips_stop",
    "night_calendar_dates"
]

sheet_id = "15zsK-lBuibUtZ1s2FxVHvAmSu-pEuE0NDT6CAMYL2TY"

for url, name in zip(urls, names):
    gid = re.search(r'gid=(\d+)', url).group(1)
    export_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"
    
    try:
        df = pd.read_csv(export_url)
        # filename = f"sheet_{gid}.csv"
        df.to_csv(f"/Volumes/transport/bronze/gtfs_static/{name}.csv", index=False)
        print(f"✅ {name} — {len(df)} lignes, {len(df.columns)} colonnes")
    except Exception as e:
        print(f"❌ Erreur pour gid={gid} : {e}")
