# %%
from pyspark.sql import functions as F

# %%
dbutils.widgets.text("runid", "2026-05-13_12-43-46")
runid = dbutils.widgets.get("runid")

print(runid)

# %% [markdown]
# # stop.txt

# %%
display(dbutils.fs.ls("/Volumes/transport/bronze/gtfs_static/"))

# %%
df_stop = (
    spark.read.format("csv")
    .option("header", "true")
    .option("inferSchema", "true")
    .load("/Volumes/transport/bronze/gtfs_static/stops-2026-05-13_12-43-46.txt")
)
